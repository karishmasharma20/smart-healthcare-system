# %%
import joblib
import os
import pandas as pd
print(os.listdir("models"))
rf = joblib.load("models/disease_model.pkl")
le = joblib.load("models/label_encoder.pkl")
# Out:
# ['disease_model.pkl', 'label_encoder.pkl']

# %%
import os

print(os.listdir())
print(os.listdir("models"))
# Out:
# ['.git', '.ipynb_checkpoints', '01_Data_Cleaning.ipynb', '03_Model_Testing.ipynb', 'data', 'models']
# ['disease_model.pkl', 'label_encoder.pkl']

# %%
input_data = pd.DataFrame(
    0,
    index=[0],
    columns=rf.feature_names_in_
)
input_data["itching"] = 1
input_data["skin_rash"] = 1
input_data["nodal_skin_eruptions"] = 1
input_data["dischromic _patches" ] = 1
input_data.head()
# Out:
#    abdominal_pain  abnormal_menstruation  acidity  acute_liver_failure  \
# 0               0                      0        0                    0
#
#    altered_sensorium  anxiety  back_pain  belly_pain  blackheads  \
# 0                  0        0          0           0           0
#
#    bladder_discomfort  ...  vomiting  watering_from_eyes  weakness_in_limbs  \
# 0                   0  ...         0                   0                  0
#
#    weakness_of_one_body_side  weight_gain  weight_loss  yellow_crust_ooze  \
# 0                          0            0            0                  0
#
#    yellow_urine  yellowing_of_eyes  yellowish_skin
# 0             0                  0               0
#
# [1 rows x 131 columns]

# %%
prediction = rf.predict(input_data)

disease = le.inverse_transform(prediction)

print("Predicted Disease:", disease[0])
# Out:
# Predicted Disease: Fungal infection
